# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, lfilter_zi

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a
def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    zi = lfilter_zi(b, a) * data[0]
    y, _ = lfilter(b, a, data, zi=zi)
    return y

# %%
sampling_frequency = 256
df = pd.read_csv('back-1.csv')
print(df.columns[0])
alpha1 = butter_bandpass_filter(data = df[' EXG Channel 0'], lowcut = 8, highcut = 13, fs = sampling_frequency, order = 3)
alpha2 = butter_bandpass_filter(data = df[' EXG Channel 1'], lowcut = 8, highcut =13, fs= sampling_frequency, order=3)
alpha3 = butter_bandpass_filter(data = df[' EXG Channel 2'], lowcut = 8, highcut =13, fs= sampling_frequency, order=3)
alpha4 = butter_bandpass_filter(data = df[' EXG Channel 3'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)

df = pd.read_csv('down-1.csv')
alpha11 = butter_bandpass_filter(data = df[' EXG Channel 0'], lowcut = 8, highcut= 13, fs = sampling_frequency, order = 3)
alpha21 = butter_bandpass_filter(data = df[' EXG Channel 1'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha31 = butter_bandpass_filter(data = df[' EXG Channel 2'], lowcut = 8, highcut =13, fs= sampling_frequency, order=3)
alpha41 = butter_bandpass_filter(data = df[' EXG Channel 3'], lowcut = 8, highcut =13, fs= sampling_frequency, order=3)

df = pd.read_csv('forward-1.csv')
alpha12 = butter_bandpass_filter(data = df[' EXG Channel 0'], lowcut = 8, highcut= 13, fs = sampling_frequency, order = 3)
alpha22 = butter_bandpass_filter(data = df[' EXG Channel 1'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha32 = butter_bandpass_filter(data = df[' EXG Channel 2'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha42 = butter_bandpass_filter(data = df[' EXG Channel 3'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)

df = pd.read_csv('left-1.csv')
alpha13 = butter_bandpass_filter(data = df[' EXG Channel 0'], lowcut = 8, highcut = 13, fs = sampling_frequency, order = 3)
alpha23 = butter_bandpass_filter(data = df[' EXG Channel 1'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha33 = butter_bandpass_filter(data = df[' EXG Channel 2'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha43 = butter_bandpass_filter(data = df[' EXG Channel 3'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
df = pd.read_csv('right-1.csv')
alpha14 = butter_bandpass_filter(data = df[' EXG Channel 0'], lowcut = 8, highcut= 13, fs = sampling_frequency, order = 3)
alpha24 = butter_bandpass_filter(data = df[' EXG Channel 1'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha34 = butter_bandpass_filter(data = df[' EXG Channel 2'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha44 = butter_bandpass_filter(data = df[' EXG Channel 3'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
df = pd.read_csv('up-1.csv')
alpha15 = butter_bandpass_filter(data = df[' EXG Channel 0'], lowcut = 8, highcut=13, fs = sampling_frequency, order = 3)
alpha25 = butter_bandpass_filter(data = df[' EXG Channel 1'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha35 = butter_bandpass_filter(data = df[' EXG Channel 2'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
alpha45 = butter_bandpass_filter(data = df[' EXG Channel 3'], lowcut = 8, highcut=13, fs= sampling_frequency, order=3)
# Out:
#  EXG Channel 0

# %%
print(alpha1)
# Out:
# [-9.05764352e-12 -1.62964939e-03 -1.09028610e-02 ... -2.32843849e+00
#  -2.34102061e+00 -2.22762944e+00]

# %%
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha1, linewidth=3)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha11, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha12, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha13, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha14, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha15, linewidth=2)
plt.show()

# %%
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha2, linewidth=3)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha21, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha22, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha23, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha24, linewidth=2)
plt.show()
fig = plt.figure(1)
plt.subplot(6,1,1)
plt.plot(alpha25, linewidth=2)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.signal import iirnotch, freqz, filtfilt

# %%
def filter_data(datt):
  band_pass_eeg = butter_bandpass_filter(data = datt[' EXG Channel 0'], lowcut = 8,highcut = 13, fs = 256, order = 3)
  b_notch, a_notch = iirnotch(w0=59.9250936329588, Q=20, fs=256)
  filtered_eeg = filtfilt(b_notch, a_notch, band_pass_eeg)
  number_of_points = len(filtered_eeg)
  fhat = np.fft.fft(filtered_eeg, number_of_points)
  PSD = fhat * np.conj(fhat) / number_of_points
  freq = (1/(0.004*number_of_points))*np.arange(number_of_points)
  L = np.arange(1,np.floor(number_of_points/2),dtype='int')
  indices = PSD > 150
  PSDclean = PSD * indices
  fhat = indices * fhat
  ffilt = np.fft.ifft(fhat)
  fig,axs = plt.subplots(3,1)
  data_points = np.arange(number_of_points)
  plt.sca(axs[0])
  plt.plot(data_points,band_pass_eeg, color='k',linewidth=1.5,label='Bandpass filter')
  plt.xlim(data_points[0],data_points[-1])
  plt.legend()

  plt.sca(axs[1])
  plt.plot(data_points,ffilt,color='b',linewidth=2,label='FFT Filtered')
  plt.xlim(data_points[0],data_points[-1])
  plt.legend()

  plt.sca(axs[2])
  plt.plot(freq[L][3:75],PSD[L][3:75],color='r', linewidth=2,label='Noisy')
  plt.plot(freq[L][3:75],PSDclean[L][3:75],color='b',linewidth=1.5,label='Filtered')
  plt.legend()
  plt.xticks(freq[L][3:75:5])

# %%
df = pd.read_csv('back-1.csv')
filter_data(df)
df = pd.read_csv('down-1.csv')
filter_data(df)
df = pd.read_csv('forward-1.csv')
filter_data(df)
df = pd.read_csv('left-1.csv')
filter_data(df)
df = pd.read_csv('right-1.csv')
filter_data(df)
df = pd.read_csv('up-1.csv')
filter_data(df)
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1317: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# ...
